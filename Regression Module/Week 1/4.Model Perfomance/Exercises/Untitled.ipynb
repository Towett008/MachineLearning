# %%
Additional resources: Model performance
© ExploreAI Academy

This reference document is designed to complement and enhance the material we have covered on model performance. It contains additional resources on model performance metrics as well as splitting datasets.

References:
A Khan Academy lesson on how to compute R-squared:
R-Squared Explained
Learn how to calculate the mean squared error by using Python code:
Calculating Mean Squared Error in Python
Learn about assessing model accuracy and understand bias-variance trade-off:
Assessing Model Accuracy and Bias-Variance Trade-off [ISLR Series]
An article that covers the various cross-validation techniques and how to implement them with Python code:
Cross-Validation Techniques
Articles that explain what validation sets are, their importance in the model-building process, and how they differ from test sets:
Training, Validation, and Test Sets
Difference Between Test and Validation Datasets
